# %% [markdown]
# # Steps to use wandb

# %%
# !pip install wandb

# %% [markdown]
# # 1. Configure a sweep ID

# %%
# !wandb sweep sweep_config.yaml
# Out:
# wandb: Creating sweep from: sweep_config.yaml
# wandb: Creating sweep with ID: fjagpvmd
# wandb: View sweep at: https://wandb.ai/lmb2332-/blood_glucose_forecaster/sweeps/fjagpvmd
# wandb: Run sweep agent with: wandb agent lmb2332-/blood_glucose_forecaster/fjagpvmd

# %% [markdown]
# # 2. Use that sweep ID in your agent run

# %%
# !wandb agent lmb2332-/blood_glucose_forecaster/fjagpvmd
# Out:
# wandb: Starting wandb agent 🕵️
# 2025-04-08 18:13:13,777 - wandb.wandb_agent - INFO - Running runs: []
# 2025-04-08 18:13:14,645 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-08 18:13:14,645 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout: 0.1
# 	epochs: 20
# 	hidden_size: 16
# 	learning_rate: 0.0001
# 	loss: RMSE
# 2025-04-08 18:13:14,647 - wandb.wandb_agent - INFO - About to run command: python train.py
# 2025-04-08 18:13:19,657 - wandb.wandb_agent - INFO - Running runs: ['ymso0bqe']
# wandb: Currently logged in as: lmb2332 (lmb2332-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /Users/laurenbeede/blood_glucose_forecaster/wandb/run-20250408_181325-ymso0bqe
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run bright-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/lmb2332-/blood_glucose_forecaster
# ...
