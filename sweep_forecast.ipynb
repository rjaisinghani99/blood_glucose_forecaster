# %% [markdown]
# # Steps to use wandb

# %%
# !pip install wandb

# %% [markdown]
# # 1. Configure a sweep ID

# %%
# !wandb sweep sweep_config.yaml
# Out:
# wandb: Creating sweep from: sweep_config.yaml
# wandb: Creating sweep with ID: xnr8jekk
# wandb: View sweep at: https://wandb.ai/lmb2332-/blood_glucose_forecaster/sweeps/xnr8jekk
# wandb: Run sweep agent with: wandb agent lmb2332-/blood_glucose_forecaster/xnr8jekk

# %% [markdown]
# # 2. Use that sweep ID in your agent run

# %%
# !wandb agent lmb2332-/blood_glucose_forecaster/xnr8jekk
# Out:
# wandb: Starting wandb agent 🕵️
# 2025-04-08 14:57:24,857 - wandb.wandb_agent - INFO - Running runs: []
# 2025-04-08 14:57:25,410 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-08 14:57:25,410 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout: 0.1
# 	epochs: 1
# 	hidden_size: 16
# 	learning_rate: 0.0001
# 	loss: RMSE
# 2025-04-08 14:57:25,414 - wandb.wandb_agent - INFO - About to run command: python train.py
# wandb: Currently logged in as: lmb2332 (lmb2332-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# 2025-04-08 14:57:30,425 - wandb.wandb_agent - INFO - Running runs: ['lmmhqqy1']
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /Users/laurenbeede/blood_glucose_forecaster/wandb/run-20250408_145730-lmmhqqy1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run kind-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/lmb2332-/blood_glucose_forecaster
# wandb: 🧹 View sweep at https://wandb.ai/lmb2332-/blood_glucose_forecaster/sweeps/xnr8jekk
# wandb: 🚀 View run at https://wandb.ai/lmb2332-/blood_glucose_forecaster/runs/lmmhqqy1
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loggers/wandb.py:397: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'hidden_size' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# Model is LightningModule: True
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#    | Name                               | Type                            | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | loss                               | RMSE                            | 0      | train
# 1  | logging_metrics                    | ModuleList                      | 0      | train
# 2  | input_embeddings                   | MultiEmbedding                  | 0      | train
# 3  | prescalers                         | ModuleDict                      | 32     | train
# 4  | static_variable_selection          | VariableSelectionNetwork        | 0      | train
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 1.2 K  | train
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 528    | train
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K  | train
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K  | train
# 11 | lstm_encoder                       | LSTM                            | 2.2 K  | train
# 12 | lstm_decoder                       | LSTM                            | 2.2 K  | train
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544    | train
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32     | train
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K  | train
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K  | train
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576    | train
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K  | train
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576    | train
# 20 | output_layer                       | Linear                          | 17     | train
# ------------------------------------------------------------------------------------------------
# 15.8 K    Trainable params
# 0         Non-trainable params
# 15.8 K    Total params
# 0.063     Total estimated model params size (MB)
# 170       Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden_size' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s]/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/_tft.py:724: UserWarning: MPS: nonzero op is supported natively starting from macOS 14.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Indexing.mm:401.)
#   decoder_attention[
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# Epoch 0: 100%|█| 343/343 [03:01<00:00,  1.89it/s, v_num=qqy1, train_loss_step=55
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|██████████          | 1/2 [00:00<00:00,  6.03it/s]
# Validation DataLoader 0: 100%|████████████████████| 2/2 [00:00<00:00,  5.71it/s]
# Epoch 0: 100%|█| 343/343 [03:01<00:00,  1.89it/s, v_num=qqy1, train_loss_step=55`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 343/343 [03:02<00:00,  1.88it/s, v_num=qqy1, train_loss_step=55
# wandb: 0.363 MB of 0.363 MB uploaded
# wandb: 0.363 MB of 0.374 MB uploaded
# wandb: 0.365 MB of 0.374 MB uploaded
# wandb: 0.374 MB of 0.374 MB uploaded
# wandb:
# wandb: 0.374 MB of 0.374 MB uploaded
# wandb:
# wandb: Run history:
# wandb:               epoch ▁▁▁▁▁▁▁▁
# wandb:    train_loss_epoch ▁
# wandb:     train_loss_step █▆▄▁▁▁
# wandb: trainer/global_step ▁▂▃▅▆▇██
# wandb:             val_MAE ▁
# wandb:            val_MAPE ▁
# wandb:            val_RMSE ▁
# wandb:           val_SMAPE ▁
# wandb:            val_loss ▁
# wandb:
# wandb: Run summary:
# wandb:               epoch 0
# wandb:    train_loss_epoch 58.88111
# wandb:     train_loss_step 53.70051
# wandb: trainer/global_step 342
# wandb:             val_MAE 38.13848
# wandb:            val_MAPE 0.27776
# wandb:            val_RMSE 48.31259
# wandb:           val_SMAPE 0.23365
# wandb:            val_loss 48.31259
# wandb:
# wandb: 🚀 View run kind-sweep-1 at: https://wandb.ai/lmb2332-/blood_glucose_forecaster/runs/lmmhqqy1
# wandb: ⭐️ View project at: https://wandb.ai/lmb2332-/blood_glucose_forecaster
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250408_145730-lmmhqqy1/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-08 15:02:06,175 - wandb.wandb_agent - INFO - Cleaning up finished run: lmmhqqy1
# 2025-04-08 15:02:07,125 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-08 15:02:07,125 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout: 0.1
# 	epochs: 1
# 	hidden_size: 16
# 	learning_rate: 0.0001
# 	loss: MAE
# 2025-04-08 15:02:07,128 - wandb.wandb_agent - INFO - About to run command: python train.py
# 2025-04-08 15:02:12,139 - wandb.wandb_agent - INFO - Running runs: ['8y58h2hl']
# wandb: Currently logged in as: lmb2332 (lmb2332-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ Waiting for wandb.init()...
# wandb: ⣟ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /Users/laurenbeede/blood_glucose_forecaster/wandb/run-20250408_150212-8y58h2hl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run restful-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/lmb2332-/blood_glucose_forecaster
# wandb: 🧹 View sweep at https://wandb.ai/lmb2332-/blood_glucose_forecaster/sweeps/xnr8jekk
# wandb: 🚀 View run at https://wandb.ai/lmb2332-/blood_glucose_forecaster/runs/8y58h2hl
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loggers/wandb.py:397: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'hidden_size' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# Model is LightningModule: True
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#    | Name                               | Type                            | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | loss                               | MAE                             | 0      | train
# 1  | logging_metrics                    | ModuleList                      | 0      | train
# 2  | input_embeddings                   | MultiEmbedding                  | 0      | train
# 3  | prescalers                         | ModuleDict                      | 32     | train
# 4  | static_variable_selection          | VariableSelectionNetwork        | 0      | train
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 1.2 K  | train
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 528    | train
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K  | train
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K  | train
# 11 | lstm_encoder                       | LSTM                            | 2.2 K  | train
# 12 | lstm_decoder                       | LSTM                            | 2.2 K  | train
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544    | train
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32     | train
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K  | train
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K  | train
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576    | train
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K  | train
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576    | train
# 20 | output_layer                       | Linear                          | 17     | train
# ------------------------------------------------------------------------------------------------
# 15.8 K    Trainable params
# 0         Non-trainable params
# 15.8 K    Total params
# 0.063     Total estimated model params size (MB)
# 170       Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'hidden_size' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dropout' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s]/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/_tft.py:724: UserWarning: MPS: nonzero op is supported natively starting from macOS 14.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Indexing.mm:401.)
#   decoder_attention[
# /Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# Epoch 0:  29%|▎| 99/343 [00:51<02:08,  1.91it/s, v_num=h2hl, train_loss_step=48.^C
# Traceback (most recent call last):
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 48, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 599, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1012, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1056, in _run_stage
#     self.fit_loop.run()
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/fit_loop.py", line 216, in run
#     self.advance()
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/fit_loop.py", line 455, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 150, in run
#     self.advance(data_fetcher)
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 320, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 192, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 270, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 176, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/core/module.py", line 1302, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/core/optimizer.py", line 154, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py", line 239, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/plugins/precision/precision.py", line 123, in optimizer_step
#     return optimizer.step(closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/optim/optimizer.py", line 493, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/optim/optimizer.py", line 91, in _use_grad
#     ret = func(self, *args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/optim/adam.py", line 223, in step
#     loss = closure()
#            ^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/plugins/precision/precision.py", line 109, in _wrap_closure
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 146, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 131, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 319, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 328, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py", line 391, in training_step
#     return self.lightning_module.training_step(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/base_model.py", line 717, in training_step
#     log, out = self.step(x, y, batch_idx)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/base_model.py", line 912, in step
#     out = self(x, **kwargs)
#           ^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/_tft.py", line 558, in forward
#     self.encoder_variable_selection(
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py", line 375, in forward
#     var_outputs.append(self.single_variable_grns[name](variable_embedding))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py", line 270, in forward
#     residual = self.resample_norm(residual)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py", line 142, in forward
#     x = self.resample(x)
#         ^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py", line 77, in forward
#     y = self.interpolate(x_reshape)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py", line 55, in interpolate
#     x = x.to("cpu")
#         ^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/laurenbeede/blood_glucose_forecaster/train.py", line 126, in train
#     trainer.fit(tft, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader)
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 561, in fit
#     call._call_and_handle_interrupt(
#   File "/Users/laurenbeede/blood_glucose_forecaster/env/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 65, in _call_and_handle_interrupt
#     exit(1)
#   File "<frozen _sitebuiltins>", line 26, in __call__
# SystemExit: 1
